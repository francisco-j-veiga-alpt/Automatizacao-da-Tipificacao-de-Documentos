# %%
from pymongo import MongoClient

# MongoDB connection details
mongo_uri = "mongodb://admin:admin1234@127.0.0.1:27017"  # Replace with your MongoDB URI
database_name = "db_sales"  # Replace with your database name
collection_name = "compras"  # Replace with your collection name

# Connect to MongoDB
# Create a MongoClient object
client = MongoClient(mongo_uri)

# Access the database

# %%
# Access the database
db = client[database_name]

# Access the collection
collection = db[collection_name]
# Out:
# ['users']

# %%
db.list_collection_names()
# Out:
# ['users', 'compras']

# %%
collection.insert_one({"id_client":3, "quantidade":200, "id_produto":20})
# Out:
# InsertOneResult(ObjectId('67c9c6e22256eeae86c42fee'), acknowledged=True)

# %%
list(collection.find())
# Out:
# [{'_id': ObjectId('67c9a9582256eeae86c42fec'),
#   'id_client': 1,
#   'quantidade': 10,
#   'id_produto': 1},
#  {'_id': ObjectId('67c9a9da2256eeae86c42fed'),
#   'id_client': 2,
#   'quantidade': 100,
#   'id_produto': 10},
#  {'_id': ObjectId('67c9c6e22256eeae86c42fee'),
#   'id_client': 3,
#   'quantidade': 200,
#   'id_produto': 20}]

# %%
collection = db[collection_name]
