# %%
from src.conn_utils.mongo_conn import connect_to_collection
from datetime import datetime
 
uri_feedback = f"mongodb://access_principal:access1234@127.0.0.1:27017/customer_feedback"
uri_admin = "mongodb://admin:admin1234@127.0.0.1:27017/admin" 
db, collection, client = connect_to_collection(uri_admin, "customer_feedback", "portal_da_queixa")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# File c:\Users\xid22687\Desktop\Projects\CFI\Automatizacao-da-Tipificacao-de-Documentos\app\backend\src\conn_utils\mongo_conn.py:108, in connect_to_collection(conn_str, db_name, collection_name, create_collection)
#     107 # Ensure collection exists if not creating
# --> 108 if not create_collection and collection_name not in db.list_collection_names():
#     109      raise ValueError(f"Collection '{collection_name}' does not exist in database '{db_name}'.")
#
# File c:\Users\xid22687\Desktop\Projects\CFI\Automatizacao-da-Tipificacao-de-Documentos\.venv\Lib\site-packages\pymongo\synchronous\database.py:1226, in Database.list_collection_names(self, session, filter, comment, **kwargs)
#    1201 """Get a list of all the collection names in this database.
#    1202
#    1203 For example, to list all non-system collections::
# ...

# %%
from pymongo import MongoClient

try:
    uri_admin = "mongodb://admin:admin1234@127.0.0.1:27017/admin"
    client = MongoClient(uri_admin)
    # Force a connection to verify it works
    client.server_info()
    print("Connection successful!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connection failed: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}

# %%
from src.conn_utils.mongo_conn import connect_to_collection
from datetime import datetime
from pymongo import MongoClient
 
uri_feedback = f"mongodb://access_principal:access1234@localhost:27017/customer_feedback"
 
db, collection, client = connect_to_collection(uri_feedback, "customer_feedback", "portal_da_queixa")
 
#client = MongoClient(f"mongodb://admin:admin1234@localhost:27017")
#db = client[db_name]
 
#client.list_database_names()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# File c:\Users\xid22687\Desktop\Projects\CFI\Automatizacao-da-Tipificacao-de-Documentos\app\backend\src\conn_utils\mongo_conn.py:108, in connect_to_collection(conn_str, db_name, collection_name, create_collection)
#     107 # Ensure collection exists if not creating
# --> 108 if not create_collection and collection_name not in db.list_collection_names():
#     109      raise ValueError(f"Collection '{collection_name}' does not exist in database '{db_name}'.")
#
# File c:\Users\xid22687\Desktop\Projects\CFI\Automatizacao-da-Tipificacao-de-Documentos\.venv\Lib\site-packages\pymongo\synchronous\database.py:1226, in Database.list_collection_names(self, session, filter, comment, **kwargs)
#    1201 """Get a list of all the collection names in this database.
#    1202
#    1203 For example, to list all non-system collections::
# ...

# %%
from pymongo import MongoClient


conn_str = f"mongodb://access_principal:access1234@127.0.0.1:27017/customer_feedback"
client = MongoClient(conn_str)
db = client["customer_feedback"]

# %%
db.list_collection_names()
# Out:
# ['classifications',
#  'portal_da_queixa_reports',
#  'qualtrics_chatbot_reports',
#  'qualtrics_chatbot',
#  'customer_feedback',
#  'cliente_misterio',
#  'portal_da_queixa_copy',
#  'cliente_misterio_reports',
#  'qualtrics_feedback',
#  'portal_da_queixa',
#  'qualtrics_feedback_reports']

# %% [markdown]
# ### Queixas Raw

# %%
collectionPQ = db["portal_da_queixa"]
collectionPQ.find_one()
# Out:
# {'_id': ObjectId('67b9bdc6ae39305d2b0bb5f0'),
#  'area_de_feedback': 'Faturamento e Pagamentos',
#  'classificacao': 'Reclamação',
#  'assunto': 'Cobrança indevida',
#  'sentimento': 'Negativo',
#  'urgente': 'Não',
#  'data': datetime.datetime(2024, 12, 31, 0, 0),
#  'utilizador': 'ELIAS MACHADO GALVAO FORTES',
#  'titulo': 'MEO - Fatura indevida',
#  'resumo': 'Cliente reclama de cobrança indevida de taxa de visita técnica, após promessa de isenção devido a problemas recorrentes com a internet.',
#  'feedback': 'Tenho problema na internet desde que contratei o serviço, são várias reclamações desde então.Para resolver o problema a operadora ofereceu enviar um técnico em minha casa sem cobrança de taxa do mesmo, portanto foi cobrado indevidamente quase 43€  '}

# %%
collectionCF = db["customer_feedback"]
collectionCF.find_one()
# Out:
# {'_id': ObjectId('67ec03f8c944573ac44ae5c7'),
#  'date': datetime.datetime(2024, 12, 31, 0, 0),
#  'user_id': 'ELIAS MACHADO GALVAO FORTES',
#  'feedback_full_text': 'MEO - Fatura indevida \nTenho problema na internet desde que contratei o serviço, são várias reclamações desde então.Para resolver o problema a operadora ofereceu enviar um técnico em minha casa sem cobrança de taxa do mesmo, portanto foi cobrado indevidamente quase 43€',
#  'source': 'portal_da_queixa',
#  'feedback_summary': 'Cliente relata problemas contínuos na internet e cobrança indevida de taxa por visita técnica.',
#  'classification': 'Facturação e saldos>Interv. tecnica por avaria',
#  'sentiment': 'Very Negative',
#  'needs_review': False}

# %%
collectionCF = db["classifications"]
collectionCF.find_one()
# Out:
# {'_id': ObjectId('67dd7e827450fb354fcb2934'),
#  'classifications': 'Adesão ou Activação>Demora>Activação de BLM'}

# %%
collectionCF = db["qualtrics_feedback"]
collectionCF.find_one()
# Out:
# {'_id': ObjectId('67ec5ee7bc4784a95d9cc8ed'),
#  'date': datetime.datetime(2025, 2, 28, 0, 0),
#  'id_source': '3-849830017070',
#  'source': 'Provedoria Cliente',
#  'crm_classification': 'Provisão>Demora>Fixo - pendência técnica',
#  'feedback': 'Assegurar PDO disponível antes da deslocação do técnico para instalação do serviço em nova morada.',
#  'sentiment': 'Negative',
#  'source_qualtrics': 'provedoria'}

# %%
collectionCF = db["qualtrics_feedback_reports"]
collectionCF.find_one()
# Out:
# {'_id': ObjectId('67eefda3510d89a0a10f5f7b'),
#  'customer_suggestions': ['Melhorar a rapidez na resolução de problemas técnicos e avarias.',
#   'Formar melhor os colaboradores para um atendimento mais eficaz e empático.',
#   'Ser mais transparente e claro nas informações sobre taxas e contratos.',
#   'Oferecer compensações adequadas por falhas no serviço.',
#   'Facilitar o contacto com o atendimento ao cliente, evitando respostas automatizadas.'],
#  'ai_improvement_proposals': ['Implementar um sistema de resposta rápida para avarias críticas, com tempo máximo de espera de 12 horas.',
#   'Revisar e melhorar o processo de formação dos colaboradores para garantir um atendimento mais humano e eficaz.',
#   'Criar um canal de comunicação direto e acessível para reclamações, evitando o uso excessivo de chatbots.',
#   'Estabelecer um programa de compensação para clientes afetados por falhas prolongadas no serviço.',
# ...

# %%
from pymongo import MongoClient

# Test basic connection without auth
try:
    client = MongoClient("mongodb://127.0.0.1:27017/")
    print("MongoDB server is reachable")
except Exception as e:
    print(f"Cannot reach MongoDB: {e}")
# Out:
# MongoDB server is reachable

# %%
try:
    uri_admin = "mongodb://admin:admin1234@127.0.0.1:27017/admin?authSource=admin&authMechanism=SCRAM-SHA-256"
    client = MongoClient(uri_admin)
    client.server_info()
    print("Connection successful!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connection successful!

# %%
# %docker logs automatizacao-da-tipificacao-de-documentos-mongo_db-1
# Out:
# UsageError: Line magic function `%docker` not found.
